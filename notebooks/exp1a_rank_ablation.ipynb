# %% [markdown]
# # Experiment 1-A: Rank Ablation (LoRA only, no full fine-tuning)
#
# Same 3 tasks and 3 LoRA ranks as experiment 1, but with the full fine-tuning baseline removed entirely. Split into **three separate cells, one per task**, since running each task separately is easier across a few shorter Colab sessions than one long one: each cell is independently runnable/resumable (if a Colab session disconnects partway through, you only lose the currently-running task's cell, not the whole sweep). All three write to the same `exp1a_rank_ablation` output folder and append to the same `metrics.jsonl`, so the final plotting cell aggregates across all three regardless of whether they ran in the same session or three different ones.
#
# Run `colab_bootstrap.ipynb`'s steps first (mount Drive, get code, install deps), then run the three task cells below in any order (or across separate sessions), then the plotting cell.
#
# Config: `src/config/experiment_1a_rank_ablation.yaml`

# %%
# Task 1/3: SST-2
# Called in-process (not `!python ...`) so tqdm's progress bars are the
# only thing that render in this cell's output -- see colab_bootstrap.ipynb's
# run-experiment cell for why.
import sys
sys.path.insert(0, "scripts")
from run_experiment import main as run_experiment

run_experiment([
    "--config", "src/config/experiment_1a_rank_ablation.yaml",
    "--task", "sst2",
    "--device", "cuda",
    "--output-root", "/content/drive/MyDrive/lora_experiments_outputs",
])

# %%
# Task 2/3: RTE
import sys
sys.path.insert(0, "scripts")
from run_experiment import main as run_experiment

run_experiment([
    "--config", "src/config/experiment_1a_rank_ablation.yaml",
    "--task", "rte",
    "--device", "cuda",
    "--output-root", "/content/drive/MyDrive/lora_experiments_outputs",
])

# %%
# Task 3/3: GSM8K
import sys
sys.path.insert(0, "scripts")
from run_experiment import main as run_experiment

run_experiment([
    "--config", "src/config/experiment_1a_rank_ablation.yaml",
    "--task", "gsm8k",
    "--device", "cuda",
    "--output-root", "/content/drive/MyDrive/lora_experiments_outputs",
])

# %%
# Plot once all three task cells above have completed (in this session or
# prior ones) -- reads the shared metrics.jsonl, which has accumulated rows
# from every --task invocation so far.
# !python scripts/plot_results.py \
    --metrics /content/drive/MyDrive/lora_experiments_outputs/exp1a_rank_ablation/metrics.jsonl \
    --output-dir /content/drive/MyDrive/lora_experiments_outputs/exp1a_rank_ablation/plots
