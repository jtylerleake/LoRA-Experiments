# %% [markdown]
# # Experiment 1: Rank Ablation
#
# Run `colab_bootstrap.ipynb`'s steps first (mount Drive, get code, install deps), then run the cell below.
#
# Config: `src/config/experiment_1_rank_ablation.yaml`

# %%
# !python scripts/run_experiment.py \
    --config src/config/experiment_1_rank_ablation.yaml \
    --device cuda \
    --output-root /content/drive/MyDrive/lora_experiments_outputs

# %%
# Generate the accuracy-vs-params, accuracy-vs-rank, and per-task training-curve
# plots directly against the Drive-mounted metrics.jsonl (no local sync needed
# in Colab — Drive is already mounted at /content/drive).
# !python scripts/plot_results.py \
    --metrics /content/drive/MyDrive/lora_experiments_outputs/exp1_rank_ablation/metrics.jsonl \
    --output-dir /content/drive/MyDrive/lora_experiments_outputs/exp1_rank_ablation/plots
