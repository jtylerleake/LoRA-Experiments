# %% [markdown]
# # Experiment 1-A: Rank Ablation (mini smoke test)
#
# Same per-task split as `exp1a_rank_ablation.ipynb`, but pointed at the mini config (~32 training examples, 1 epoch per run) so all three task cells plus plotting finish in a couple of minutes total. Use this to verify the `--task` splitting and cross-invocation `metrics.jsonl` aggregation work correctly before committing to the full multi-hour, three-session sweep. **Accuracy numbers here are meaningless**, only the wiring matters.
#
# Run `colab_bootstrap.ipynb`'s steps first (mount Drive, get code, install deps), then run the cells below in order.
#
# Config: `src/config/experiment_1a_rank_ablation_mini.yaml`

# %%
# Task 1/3: SST-2
# !python scripts/run_experiment.py \
    --config src/config/experiment_1a_rank_ablation_mini.yaml \
    --task sst2 \
    --device cuda \
    --output-root /content/drive/MyDrive/lora_experiments_outputs

# %%
# Task 2/3: RTE
# !python scripts/run_experiment.py \
    --config src/config/experiment_1a_rank_ablation_mini.yaml \
    --task rte \
    --device cuda \
    --output-root /content/drive/MyDrive/lora_experiments_outputs

# %%
# Task 3/3: GSM8K
# !python scripts/run_experiment.py \
    --config src/config/experiment_1a_rank_ablation_mini.yaml \
    --task gsm8k \
    --device cuda \
    --output-root /content/drive/MyDrive/lora_experiments_outputs

# %%
# !python scripts/plot_results.py \
    --metrics /content/drive/MyDrive/lora_experiments_outputs/exp1a_rank_ablation_mini/metrics.jsonl \
    --output-dir /content/drive/MyDrive/lora_experiments_outputs/exp1a_rank_ablation_mini/plots
