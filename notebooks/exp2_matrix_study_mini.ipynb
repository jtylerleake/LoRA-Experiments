# %% [markdown]
# # Experiment 2: Matrix Application Study (mini smoke test)
#
# Same 6 target-module variants (fixed LoRA rank 8) as the full experiment, but capped to ~32 training examples and 1 epoch per run, so all 6 runs finish in a couple of minutes instead of much longer. Use this to verify training and `metrics.jsonl` work end-to-end before committing GPU time to the full sweep — **accuracy numbers here are meaningless**, only the wiring matters.
#
# Run `colab_bootstrap.ipynb`'s steps first (mount Drive, get code, install deps), then run the cell below. Writes to a separate `exp2_matrix_study_mini` output folder so it never touches the full run's results.
#
# Config: `src/config/experiment_2_matrix_study_mini.yaml`

# %%
# !python scripts/run_experiment.py \
    --config src/config/experiment_2_matrix_study_mini.yaml \
    --device cuda \
    --output-root /content/drive/MyDrive/lora_experiments_outputs
